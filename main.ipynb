# %%
# !nvidia-smi
# Out:
# Thu May  7 18:35:50 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.71.05              Driver Version: 595.71.05      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...    Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   57C    P3             13W /   40W |    1251MiB /   8188MiB |      2%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1371      G   niri                                     34MiB |
# |    0   N/A  N/A            1915      C   ./linux-wallpaperengine                 576MiB |
# |    0   N/A  N/A            1916      C   ./linux-wallpaperengine                 576MiB |
# |    0   N/A  N/A            3101    C+G   ...am/ubuntu12_64/steamwebhelper          5MiB |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive', force_remount=True)
#
# ModuleNotFoundError: No module named 'google'

# %%
cd '/content/gdrive/My Drive/EXP/0_Completed/2022_VisionTransformerHashing/'
# Out:
# /content/gdrive/My Drive/EXP/0_Completed/2022_VisionTransformerHashing

# %%
#!git clone https://github.com/NVIDIA/apex
#%cd apex
#!pip install -v --no-cache-dir ./
# !pip install ml_collections
# Out:
# Collecting ml_collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Collecting absl-py (from ml_collections)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: PyYAML in /home/LittleWatter/.local/lib/python3.13/site-packages (from ml_collections) (6.0.3)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Installing collected packages: absl-py, ml_collections
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ml_collections]
# Successfully installed absl-py-2.4.0 ml_collections-1.1.0

# %%
#!wget https://storage.googleapis.com/vit_models/imagenet21k/ViT-B_16.npz
#!wget https://storage.googleapis.com/vit_models/imagenet21k/ViT-B_32.npz

# %%
# !python DSH.py
#!python HashNet.py
#!python GreedyHash.py
#!python IDHN.py
#!python CSQ.py
#!python DPN.py

#!python DSHcls.py
#!python HashNetcls.py
#!python GreedyHashcls.py
#!python IDHNcls.py
#!python CSQcls.py
#!python DPNcls.py
# Out:
# Error processing line 1 of /home/LittleWatter/.conda/envs/torch/lib/python3.11/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "<frozen site>", line 195, in addpackage
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
# /home/LittleWatter/.conda/envs/torch/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/LittleWatter/.conda/envs/torch/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# {'dataset': 'cifar10', 'net': <class 'TransformerModel.modeling.VisionTransformer'>, 'net_print': 'ViT-B_32', 'model_type': 'ViT-B_32', 'pretrained_dir': 'pretrainedVIT/ViT-B_32.npz', 'bit_list': [64, 32, 16], 'optimizer': {'type': <class 'torch.optim.adam.Adam'>, 'optim_params': {'lr': 1e-05}}, 'device': device(type='cuda'), 'save_path': 'Checkpoints_Results', 'epoch': 150, 'test_map': 30, 'batch_size': 32, 'resize_size': 256, 'crop_size': 224, 'info': 'DSH', 'alpha': 0.1, 'topK': -1, 'n_class': 10, 'data_path': './dataset/cifar10/', 'data': {'train_set': {'list_path': './data/cifar10/train.txt', 'batch_size': 32}, 'database': {'list_path': './data/cifar10/database.txt', 'batch_size': 32}, 'test': {'list_path': './data/cifar10/test.txt', 'batch_size': 32}}}
# Traceback (most recent call last):
#   File "/home/LittleWatter/Code/python/deepLearning/VisionTransformerHashing/DSH.py", line 162, in <module>
#     train_val(config, bit)
#   File "/home/LittleWatter/Code/python/deepLearning/VisionTransformerHashing/DSH.py", line 42, in train_val
#     train_loader, test_loader, dataset_loader, num_train, num_test, num_dataset = get_data(config)
#                                                                                   ^^^^^^^^^^^^^^^^
#   File "/home/LittleWatter/Code/python/deepLearning/VisionTransformerHashing/utils/tools.py", line 207, in get_data
#     return cifar_dataset(config)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/LittleWatter/Code/python/deepLearning/VisionTransformerHashing/utils/tools.py", line 131, in cifar_dataset
#     train_dataset = MyCIFAR10(root=cifar_dataset_root,
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/LittleWatter/.conda/envs/torch/lib/python3.11/site-packages/torchvision/datasets/cifar.py", line 65, in __init__
#     self.download()
#   File "/home/LittleWatter/.conda/envs/torch/lib/python3.11/site-packages/torchvision/datasets/cifar.py", line 139, in download
#     download_and_extract_archive(self.url, self.root, filename=self.filename, md5=self.tgz_md5)
#   File "/home/LittleWatter/.conda/envs/torch/lib/python3.11/site-packages/torchvision/datasets/utils.py", line 434, in download_and_extract_archive
#     download_url(url, download_root, filename, md5)
#   File "/home/LittleWatter/.conda/envs/torch/lib/python3.11/site-packages/torchvision/datasets/utils.py", line 123, in download_url
#     os.makedirs(root, exist_ok=True)
#   File "<frozen os>", line 215, in makedirs
#   File "<frozen os>", line 225, in makedirs
# PermissionError: [Errno 13] Permission denied: '/dataset'
